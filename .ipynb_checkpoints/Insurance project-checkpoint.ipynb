# %% [markdown]
# # EDA + Data Cleaning

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import time

# read insurance data
data = pd.read_csv('insurance.csv')

# randomly create test and training dataset
np.random.seed(2)

train = data.sample(round(data.shape[0]*0.8)) # 80% i.e. 
test = data.drop(train.index)

print("Training data has ", train.shape[0], "observations.")
print("Test data has ", test.shape[0], "observations.")
# Out:
# Training data has  1070 observations.
# Test data has  268 observations.

# %% [markdown]
# Goal: we want to predict the price of insurance based on a persons' characteristics. We also considered inference since it would be interesting to see which personal characteristic has the most influence on insurance prices

# %% [markdown]
# ## Exploring the parameters

# %% [markdown]
# Quantitative parameters:

# %%
train.describe()
# Out:
#                age          bmi     children       charges
# count  1070.000000  1070.000000  1070.000000   1070.000000
# mean     39.081308    30.831514     1.093458  13454.331986
# std      14.021963     6.134072     1.206722  12451.054091
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.400000     0.000000   4719.577175
# 50%      39.000000    30.590000     1.000000   9289.083100
# 75%      51.000000    34.848750     2.000000  17071.645350
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# There does not seem to be any missing data in the training dataset. The four quantitiative variables are ['age', 'bmi', 'children']. Our target variable is charges. We proceed with viewing the correlation between the quantitative parameters and target variable.

# %%
train.corrwith(train['charges'])
# Out:
# age         0.304118
# bmi         0.220865
# children    0.068611
# charges     1.000000
# dtype: float64

# %% [markdown]
# All three variables seem to have positive correlation with charges. Correlation is relatively low (max 0.3). Below is a pairplot to reveal any non-linear relationships between the variables.

# %%
sns.pairplot(train)

# %% [markdown]
# Observations:
# - The relationship between age and charges seems to be linear but split into three distinct lines (by charge 'tier')
# - There seem to be two clusters in the BMI vs charges scatterplot (note the gap between charges in the two groups between BMIs of 30-40). Alternatively, this could be a sidways parabola. Either way, BMI may need to be transformed to capture non-linearity.
# - It seems like the higher the number of children, the lower the spread of charges with a tendancy to be skewed towards lower charges but this may be because there are fewer observations with larger number of children.

# %% [markdown]
# Qualitative parameters:

# %%
train.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# Qualitative parameters include ['smoker','region']. The different classes are shown below:

# %%
# smoker
train['smoker'].value_counts()
# Out:
# no     850
# yes    220
# Name: smoker, dtype: int64

# %%
sns.boxplot(x = 'smoker', y = 'charges', data = train)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# Approximately 21% of patients are smokers. The boxplot indicates there is a difference between charges of non smokers and smokers. Non-smokers have lower charges on average (median below 1k) and smaller spread. There seems to be a large number of outliers so further outlier detection is necessary for this group. Smokers have higher charges on average (median > 3.5k) and larger spread.

# %%
# region
train['region'].value_counts()
# Out:
# southeast    291
# northwest    262
# northeast    259
# southwest    258
# Name: region, dtype: int64

# %% [markdown]
# There seems to be a arelatively even distribution of individuals in each of the four regions.

# %%
sns.boxplot(x = 'region', y = 'charges', data = train)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %% [markdown]
# All regions seem to have the same median charge, but vary in terms of spread. The southeast region has the largest spread of data, followed by the northeast. On the otherhand, the north and southwest seem to have comparably low spreads. All regions have a substantial number of outliers so this will be further reviewed.

# %% [markdown]
# ## Outliers and high leverage points

# %% [markdown]
# ## Transformations

# %%
['age', 'bmi', 'children']
# Out:
# ['age', 'bmi', 'children']

# %%
# age
sns.scatterplot(data = train, x = 'age', y = 'charges')
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
# bmi
sns.scatterplot(data = train, x = 'bmi', y = 'charges')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
# children
sns.scatterplot(data = train, x = 'children', y = 'charges')
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %% [markdown]
# # Preliminary model

# %%
# function to fit lin reg model (input dataframe and formula)

def create_model(df, formula):
    # fit the model
    model = smf.ols(data = df, formula = formula).fit()
    display(model.summary())
    
    # calculate rse
    print('RSE: ', np.sqrt(model.mse_resid))
    
    # calculate rmse
    prediction = model.predict(df)
    print('RMSE: ', np.sqrt(((df.charges - prediction)**2).mean()))
    return model

# %%
# no transformations or interactions
create_model(df = train, formula = 'charges ~ age + bmi + children + smoker + region')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     487.2
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        13:59:02   Log-Likelihood:                -10838.
# No. Observations:                1070   AIC:                         2.169e+04
# Df Residuals:                    1062   BIC:                         2.173e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Variable Selection

# %%
train0
# Out:
#       age  sex     bmi  children  smoker      charges  region_northeast  \
# 17     23    0  23.845         0       0   2395.17155                 1
# 1091   55    1  29.830         0       0  11286.53870                 1
# 273    50    0  27.455         1       0   9617.66245                 1
# 270    18    0  29.370         1       0   1719.43630                 0
# 874    44    0  21.850         3       0   8891.13950                 1
# ...   ...  ...     ...       ...     ...          ...               ...
# 306    28    1  27.500         2       0  20177.67113                 0
# 415    43    1  35.640         1       0   7345.72660                 0
# 1303   43    0  27.800         0       1  37829.72420                 0
# 1131   27    0  45.900         2       0   3693.42800                 0
# 428    21    1  16.815         1       0   3167.45585                 1
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
train0 = train.copy()
train0['sex'] = train0['sex'].map({'female': 1, 'male': 0})
train0['smoker'] = train0['smoker'].map({'yes': 1, 'no': 0})
train0 = pd.get_dummies(train0)

test0 = test.copy()
test0['sex'] = test0['sex'].map({'female': 1, 'male': 0})
test0['smoker'] = test0['smoker'].map({'yes': 1, 'no': 0})
test0 = pd.get_dummies(test0)

X = train0[['age', 'sex', 'bmi', 'children', 'smoker', 'region_northeast', 'region_northwest','region_southeast','region_southwest']]
X_backup = train0[['age', 'sex', 'bmi', 'children', 'smoker', 'region_northeast', 'region_northwest','region_southeast','region_southwest']]
x = X

#Function to develop a model based on all predictors in predictor_subset
def processSubset(predictor_subset):
    # Fit model on feature_set and calculate R-squared
    model = smf.ols('charges~' + '+'.join(predictor_subset), data = train0).fit()
    Rsquared = model.rsquared
    return {"model":model, "Rsquared":Rsquared}

#Function to select the best model amongst all models with 'k' predictors
def getBest_model(k):
    tic = time.time()
    results = []
    for combo in itertools.combinations(x.columns, k): # All subsets of 2
        results.append(processSubset((list(combo)))) # are evaluated

    # Wrap everything up in a dataframe
    models = pd.DataFrame(results)

    # Choose the model with the highest RSS
    best_model = models.loc[models['Rsquared'].argmax()]
    
    toc = time.time()
    print("Processed", models.shape[0], "models on", k, "predictors in", (toc-tic), "seconds.")
    return best_model

#Function to select the best model amongst the best models for 'k' predictors, where k = 1,2,3,..
models_best = pd.DataFrame(columns=["Rsquared", "model"])

tic = time.time()
for i in range(1,1+x.shape[1]):
    models_best.loc[i] = getBest_model(i)

toc = time.time()
print("Total elapsed time:", (toc-tic), "seconds.")

processSubset(x)

def best_sub_plots():
    plt.figure(figsize=(20,10))
    plt.rcParams.update({'font.size': 18, 'lines.markersize': 10})

    # Set up a 2x2 grid so we can look at 4 plots at once
    plt.subplot(2, 2, 1)

    # We will now plot a red dot to indicate the model with the largest adjusted R^2 statistic.
    # The argmax() function can be used to identify the location of the maximum point of a vector
    plt.plot(models_best["Rsquared"])
    plt.xlabel('# Predictors')
    plt.ylabel('Rsquared')

    # We will now plot a red dot to indicate the model with the largest adjusted R^2 statistic.
    # The argmax() function can be used to identify the location of the maximum point of a vector

    rsquared_adj = models_best.apply(lambda row: row[1].rsquared_adj, axis=1)

    plt.subplot(2, 2, 2)
    plt.plot(rsquared_adj)
    plt.plot(1+rsquared_adj.argmax(), rsquared_adj.max(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('adjusted rsquared')

    # We'll do the same for AIC and BIC, this time looking for the models with the SMALLEST statistic
    aic = models_best.apply(lambda row: row[1].aic, axis=1)

    plt.subplot(2, 2, 3)
    plt.plot(aic)
    plt.plot(1+aic.argmin(), aic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('AIC')

    bic = models_best.apply(lambda row: row[1].bic, axis=1)

    plt.subplot(2, 2, 4)
    plt.plot(bic)
    plt.plot(1+bic.argmin(), bic.min(), "or")
    plt.xlabel('# Predictors')
    plt.ylabel('BIC')
print(best_sub_plots())

# Best subset is size 6 (Based on BIC)
    # Not BMI
# Out:
# Processed 9 models on 1 predictors in 0.08332324028015137 seconds.
# Processed 36 models on 2 predictors in 0.2345561981201172 seconds.
# Processed 84 models on 3 predictors in 0.66487717628479 seconds.
# Processed 126 models on 4 predictors in 1.3426287174224854 seconds.
# Processed 126 models on 5 predictors in 1.3796041011810303 seconds.
# Processed 84 models on 6 predictors in 0.9286394119262695 seconds.
# Processed 36 models on 7 predictors in 0.4506702423095703 seconds.
# Processed 9 models on 8 predictors in 0.1279001235961914 seconds.
# Processed 1 models on 9 predictors in 0.018042802810668945 seconds.
# Total elapsed time: 5.281627178192139 seconds.
# None

# %%
best_subset_model = models_best.loc[4, 'model']
models_best.loc[4, 'model'].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.760
# Method:                 Least Squares   F-statistic:                     848.2
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        14:12:12   Log-Likelihood:                -10841.
# No. Observations:                1070   AIC:                         2.169e+04
# Df Residuals:                    1065   BIC:                         2.172e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -1.22e+04   1051.114    -11.609      0.000   -1.43e+04   -1.01e+04
# ...

# %%
#Finding the RMSE of the model selected using the best subset selection procedure
pred_price = best_subset_model.predict(test0)
print(np.sqrt(((pred_price - test0.charges)**2).mean()))

#RMSE of the model using all the predictors
model = smf.ols('charges~' + '+'.join(x.columns),data = train0).fit()
pred_price = model.predict(test0)
print(np.sqrt(((pred_price - test0.charges)**2).mean()))
# Out:
# 5988.768245087889
# 5997.082350181589

# %% [markdown]
# # Subset Selection with Interactions

# %%
#Including 2-factor interactions of predictors in train and 'X'. Note that we need train to develop the model, and X to 
#find 'k' variable subsets from amongst all the predictors under consideration
for combo in itertools.combinations(X_backup.columns, 2):    
    train0['_'.join(combo)] = train0[combo[0]]*train0[combo[1]]
    test0['_'.join(combo)] = test0[combo[0]]*test0[combo[1]]
    X.loc[:,'_'.join(combo)] = train0.loc[:,'_'.join(combo)]
# Out:
# /var/folders/t9/_x5y2dys63b6nz3nw8l_vrsh0000gn/T/ipykernel_25615/1054662865.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.loc[:,'_'.join(combo)] = train0.loc[:,'_'.join(combo)]

# %%
models_best = pd.DataFrame(columns=["Rsquared", "model"])

tic = time.time()
for i in range(1,1+X.shape[1]):
    models_best.loc[i] = getBest_model(i)

toc = time.time()
print("Total elapsed time:", (toc-tic), "seconds.")
print(best_sub_plots())
# Out:
# Processed 45 models on 1 predictors in 2.5459158420562744 seconds.
# Processed 990 models on 2 predictors in 30.140963077545166 seconds.
# Processed 14190 models on 3 predictors in 521.5484569072723 seconds.

# %%
best_interaction_model = models_best['model'][7]
best_interaction_model.summary()

# %%
#Finding the RMSE of the model selected using the best subset selection procedure, where the predictors
#include 2-factor interactions
pred_price = best_interaction_model.predict(test0)
print('RMSE for best:', np.sqrt(((pred_price - test0.charges)**2).mean()),'<- this should be lower')

# RMSE of the model using all the predictors and their 2-factor interactions
pred_price = model.predict(test0)
print('RMSE for all:', np.sqrt(((pred_price - test0.charges)**2).mean()))

# %% [markdown]
# # Stepwise Selection

# %%
#Function to find the best predictor out of p-k predictors and add it to the model containing the k predictors
def forward(predictors):

    # Pull out predictors we still need to process
    remaining_predictors = [p for p in X.columns if p not in predictors]
    
    tic = time.time()
    
    results = []
    
    for p in remaining_predictors:
        results.append(processSubset(predictors+[p]))
    
    # Wrap everything up in a nice dataframe
    models = pd.DataFrame(results)
    
    # Choose the model with the highest RSS
    best_model = models.loc[models['Rsquared'].argmax()]
    
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors)+1, "predictors in", (toc-tic), "seconds.")
    
    # Return the best model, along with some other useful information about the model
    return best_model

def forward_selection():
    models_best = pd.DataFrame(columns=["Rsquared", "model"])

    tic = time.time()
    predictors = []

    for i in range(1,len(X.columns)+1):    
        models_best.loc[i] = forward(predictors)
        predictors = list(models_best.loc[i]["model"].params.index[1:])

    toc = time.time()
    print("Total elapsed time:", (toc-tic), "seconds.")
    return models_best

models_best = forward_selection()

print(best_sub_plots())
# Out:
# Processed  45 models on 1 predictors in 0.31661009788513184 seconds.
# Processed  44 models on 2 predictors in 0.42765307426452637 seconds.
# Processed  43 models on 3 predictors in 0.6244049072265625 seconds.
# Processed  42 models on 4 predictors in 0.3651740550994873 seconds.
# Processed  41 models on 5 predictors in 0.4094231128692627 seconds.
# Processed  40 models on 6 predictors in 0.4449150562286377 seconds.
# Processed  39 models on 7 predictors in 0.5026547908782959 seconds.
# Processed  38 models on 8 predictors in 0.5224709510803223 seconds.
# Processed  37 models on 9 predictors in 0.5890998840332031 seconds.
# Processed  36 models on 10 predictors in 1.0834250450134277 seconds.
# Processed  35 models on 11 predictors in 0.835191011428833 seconds.
# Processed  34 models on 12 predictors in 0.6826140880584717 seconds.
# Processed  33 models on 13 predictors in 1.1935548782348633 seconds.
# Processed  32 models on 14 predictors in 0.6892948150634766 seconds.
# ...

# %%
best_fwd_reg_model = models_best['model'][6]
best_fwd_reg_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     954.0
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):               0.00
# Time:                        14:43:41   Log-Likelihood:                -10616.
# No. Observations:                1070   AIC:                         2.125e+04
# Df Residuals:                    1063   BIC:                         2.128e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# ...

# %%
#Finding the RMSE of the model selected using the forward selection procedure, where the predictors
#include 2-factor interactions
pred_price = best_fwd_reg_model.predict(test0)
print('RMSE for forward selection:', np.sqrt(((pred_price - test0.charges)**2).mean()))

# RMSE of the model using all the predictors and their 2-factor interactions
pred_price = model.predict(test0)
print('RMSE for all:', np.sqrt(((pred_price - test0.charges)**2).mean()))
# Out:
# RMSE for forward selection: 4421.895595629771
# RMSE for all: 5997.082350181589

# %% [markdown]
# # Secondary Model

# %%
create_model(df = train, formula = 'charges ~ age + bmi + children + children*age + smoker + bmi*smoker + region')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                charges   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     630.8
# Date:                Mon, 27 Feb 2023   Prob (F-statistic):               0.00
# Time:                        18:26:44   Log-Likelihood:                -10618.
# No. Observations:                1070   AIC:                         2.126e+04
# Df Residuals:                    1060   BIC:                         2.131e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
ols_object = smf.ols(formula = 'charges ~ age + bmi + children + smoker + bmi * smoker + region', 
                     data = train)
model = ols_object.fit()
model.summary()
pred_price = model.predict(test)
print('RMSE: ', np.sqrt(((test.charges - pred_price)**2).mean()))
print('RSE: ', np.sqrt(model.mse_resid)) #RSE is greater -> underfitting
# Out:
# RMSE:  4403.306066246089
# RSE:  4960.695296506724

# %%
sns.scatterplot(x = model.fittedvalues)
# Out:
# <AxesSubplot:>
